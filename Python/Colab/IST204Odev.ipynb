# %%
import numpy as np
import pandas as pd
# !pip install isodate # isodate modülünü indirme
#(colabda dahili olmadığı için indiriyoruz)
import isodate

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/spotify2020.csv")
data2 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/spotify2021.csv")
data3 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/spotify2022.csv")
data4 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/spotify2023.csv")

data5 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/youtube2020.csv")
data6 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/youtube2021.csv")
data7 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/youtube2022.csv")
data8 = pd.read_csv("https://raw.githubusercontent.com/bymayfe/YoutubeSpotifyStatsVirtualization/main/datasets/youtube2023.csv")

# %%
statistics = data1['songPopularity'].describe().reset_index()
statistics.style.format({"number": "{:20,.0f}"}).highlight_max(color='RED')
# Out:
# <style type="text/css">
# #T_455d2_row0_col1, #T_455d2_row2_col0 {
#   background-color: RED;
# }
# </style>
# <table id="T_455d2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_455d2_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_455d2_level0_col1" class="col_heading level0 col1" >songPopularity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_455d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_455d2_row0_col0" class="data row0 col0" >count</td>
#       <td id="T_455d2_row0_col1" class="data row0 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_455d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_455d2_row1_col0" class="data row1 col0" >mean</td>
#       <td id="T_455d2_row1_col1" class="data row1 col1" >31.400000</td>
#     </tr>
#     <tr>
# ...

# %%
statistics = data2['songPopularity'].describe().reset_index()
statistics.style.format({"number": "{:20,.0f}"}).highlight_max(color='BLUE')
# Out:
# <style type="text/css">
# #T_b425b_row0_col1, #T_b425b_row2_col0 {
#   background-color: BLUE;
# }
# </style>
# <table id="T_b425b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b425b_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_b425b_level0_col1" class="col_heading level0 col1" >songPopularity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b425b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b425b_row0_col0" class="data row0 col0" >count</td>
#       <td id="T_b425b_row0_col1" class="data row0 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b425b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b425b_row1_col0" class="data row1 col0" >mean</td>
#       <td id="T_b425b_row1_col1" class="data row1 col1" >56.320000</td>
#     </tr>
#     <tr>
# ...

# %%
plt.plot(data1['songOrder'], data1['songPopularity'] , label = '2020', color="red")
plt.plot(data2['songOrder'], data2['songPopularity'] , label = '2021' , color="blue")
# plt.plot(data3['songOrder'], data3['songPopularity'] , label = '2022', color="yellow")
# plt.plot(data4['songOrder'], data4['songPopularity'] , label = '2023', color="green")
plt.title('Şarkılar')
plt.xlabel('Sıralama')
plt.ylabel('Popülerlik')
plt.show()

# %%
plt.scatter(data1['songOrder'], data1['songPopularity'], label = '2020', color="red")
# plt.scatter(data2['songOrder'], data2['songPopularity'], label = '2021')
plt.scatter(data3['songOrder'], data3['songPopularity'], label = '2022')
# plt.scatter(data4['songOrder'], data4['songPopularity'], label = '2023')
plt.title('Şarkılar')
plt.xlabel('Sıralama')
plt.ylabel('Popülerlik')
plt.show()

# %%
plt.bar(data1['songOrder'], data1['songPopularity'], label = '2020', color="red")
# plt.bar(data2['songOrder'], data2['songPopularity'], label = '2021')
# plt.bar(data3['songOrder'], data3['songPopularity'], label = '2022')
plt.bar(data4['songOrder'], data4['songPopularity'], label = '2023')
plt.title('Şarkılar')
plt.xlabel('Sıralama')
plt.ylabel('Popülerlik')
plt.show()

# %%
# dataset1'i oluşturma
dataset1 = [data1['songDuration'], data2['songDuration'], data3['songDuration']]

# dataset1'i numpy array'e çevirme ve transpoze etme
dataset1 = np.array(dataset1).T

# Görselleştirme
plt.imshow(dataset1, aspect='auto', cmap='hot')
plt.colorbar()  # Renk çubuğunu ekleme
plt.title('Şarkı Verileri Isı Haritası')
plt.xlabel('Yıllar (2020, 2021, 2022)')
plt.ylabel('Şarkılar')

# X-tick ve Y-tick etiketleri ayarlama
plt.xticks(ticks=[0, 1, 2], labels=['2020', '2021', '2022'])
plt.yticks(ticks=range(len(data1['songDuration'])), labels=data1['songOrder'])

# Grafiği gösterme
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veriler
x = np.linspace(0, 1, len(data1))
y = np.linspace(0, 1, len(data2))
X, Y = np.meshgrid(x, y)
Z = np.random.rand(len(x), len(y))  # Kontur plot için rastgele veri

# Contour plot
plt.contour(X, Y, Z, levels=10, colors='black')
plt.title('Contour Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# İlgili sütunları seçelim
duration_2020 = data1['songDuration']
duration_2023 = data4['songDuration']

# Ortak bir ölçek oluşturmak için verileri normalize edelim
popularity_2020 = (duration_2020 - np.min(duration_2020)) / (np.max(duration_2020) - np.min(duration_2020))
popularity_2021 = (duration_2023 - np.min(duration_2023)) / (np.max(duration_2023) - np.min(duration_2023))

# Grid oluşturma
X, Y = np.meshgrid(duration_2020, duration_2023)

# Fark matrisi
Z = np.abs(X - Y)

# Contour plot
plt.contour(X, Y, Z, levels=10, colors='black')
plt.title('Song Duration Contour Plot (2020 vs 2023)')
plt.xlabel('Song Duration 2020')
plt.ylabel('Song Duration 2023')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veriler
x = np.linspace(0, 1, len(data1))
y = np.linspace(0, 1, len(data3))
X, Y = np.meshgrid(x, y)
Z = np.random.rand(len(x), len(y))  # Pcolormesh plot için rastgele veri

# Pcolormesh plot
plt.pcolormesh(X, Y, Z, cmap='viridis', vmin=0, vmax=1)
plt.colorbar()
plt.title('Pcolormesh Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# İlgili sütunları seçelim
popularity_2020 = data1['songPopularity']
popularity_2021 = data2['songPopularity']

# Ortak bir ölçek oluşturmak için verileri normalize edelim
popularity_2020 = (popularity_2020 - np.min(popularity_2020)) / (np.max(popularity_2020) - np.min(popularity_2020))
popularity_2021 = (popularity_2021 - np.min(popularity_2021)) / (np.max(popularity_2021) - np.min(popularity_2021))

# Grid oluşturma
X, Y = np.meshgrid(popularity_2020, popularity_2021)

# Z matrisi (örneğin, iki yılın popülerlik değerlerinin farkı)
Z = np.abs(X - Y)

# Pcolormesh plot
plt.pcolormesh(X, Y, Z, cmap='viridis', vmin=0, vmax=1)
plt.colorbar()
plt.title('Song Popularity Pcolormesh Plot (2020 vs 2021)')
plt.xlabel('Song Popularity 2020')
plt.ylabel('Song Popularity 2021')
plt.show()

# print(data1['songPopularity'].max())
# print(data2['songPopularity'].max())
# Out:
# <ipython-input-55-e5127f6db769>:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(X, Y, Z, cmap='viridis', vmin=0, vmax=1)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veriler
x = np.arange(0, 2*np.pi, 0.2)
y = np.arange(0, 2*np.pi, 0.2)
X, Y = np.meshgrid(x, y)
U = np.cos(X)
V = np.sin(Y)

# Quiver plot
plt.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1)
plt.title('Quiver Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Yapay veri oluştur
x = np.linspace(-2, 2, 10)
y = np.linspace(-2, 2, 10)
X, Y = np.meshgrid(x, y)
U = -Y
V = X

# Quiver plot oluştur
plt.figure()
plt.quiver(X, Y, U, V, units='xy', scale=1, color='blue')
plt.title('Quiver Plot Örneği')
plt.xlabel('X ekseni')
plt.ylabel('Y ekseni')
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.grid()
plt.show()

# %%
# Veriler
sizes = data4['songDuration'][:5]  # İlk dört popülarite değeri
labels = data4['songName'][:5]  # İlk dört şarkı ismi
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', "pink"]
explode = (0.1, 0, 0, 0,0.2)  # İlk dilimi öne çıkar

# Pie plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Pie Chart')
plt.axis('equal')  # Daire şeklinde çizim
plt.show()

# %%
# Veriler
# x = np.arange(len(data5['title'][:5]))
x = data5['viewCount'][:5]
y = data5['commentCount'][:5]

# Scatter plot with text
plt.scatter(x, y)
for i in range(len(x)):
    plt.text(x[i], y[i], data5['title'][i], fontsize=12, ha='right', va='bottom')

plt.title('Scatter Plot with Text')
plt.xlabel('View Count')
plt.ylabel('Comment Count')
plt.show()
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veriler
x = np.linspace(0, 1, len(data1))
y1 = np.random.rand(len(data1))
y2 = np.random.rand(len(data1))

# Fill between plot
plt.fill_between(x, y1, y2, color='lightblue', where=(y1 > y2), interpolate=True)
plt.fill_between(x, y1, y2, color='salmon', where=(y1 <= y2), interpolate=True)
plt.title('Fill Between Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# x = np.linspace(0, 1, len(data7))
x = data7['viewCount']
y1 = data7['likeCount']
y2 = data8['likeCount']

# Fill between plot
plt.fill_between(x, y1, y2, color='lightblue', where=(y1 > y2), interpolate=True)
plt.fill_between(x, y1, y2, color='red', where=(y1 <= y2), interpolate=True)
plt.title('Fill Between Plot')
plt.xlabel('X ekseni')
plt.ylabel('Y ekseni')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veriler
data = [data5['viewCount'], data6['viewCount'], data7['viewCount'], data8['viewCount']]

# Boxplot
plt.boxplot(data, notch=True, sym='b+', widths=0.7)
plt.title('Boxplot')
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.show()

# %%
combined_data = pd.concat([data5['likeCount'], data6['likeCount'], data7['likeCount'], data8['likeCount']], axis=1)
combined_data.columns = ['2020', '2021','2022', '2023']
combined_data.plot(kind='box', title='Youtube Like Comparison: 2020, 2021, 2022 and 2023')
plt.ylabel('Like')
plt.show()

# %%
datas= [data5, data6, data7, data8]
colors = ['red', 'blue', "green", "yellow"]
count= 0
for data in datas:
  x=np.arange(len(data['description'][:10]))
  y = data['viewCount'][:10]
  yerr = np.random.rand(len(data['title'][:10])) * 10
  plt.errorbar(x,y, yerr=yerr, fmt='o', ecolor='r', capsize=5, color=colors[count])
  count+=1

plt.title('Errorbar Plot')
plt.xlabel('Description Length')
plt.ylabel('View Count (Popularity)')
plt.show()

# %%
data = [data5['commentCount'], data6["commentCount"], data7['commentCount'], data8['commentCount']]
colors = ['red', 'blue', "green", "yellow"]

# Histogram plot
plt.hist(data, bins=30, range=(0, 100), density=True, color=colors, alpha=0.75)
plt.title('Histogram')
plt.xlabel('CommentCOUNT')
plt.ylabel('Frequency')
plt.show()

# %%
data = [data5['categoryId'], data6["categoryId"], data7['categoryId'], data8['categoryId']]

# Violin plot
plt.violinplot(data, positions=[1, 2, 3, 4], widths=0.7, vert=True)
plt.title('Violin Plot')
plt.xlabel('Year')
plt.ylabel('viewCount YT')
plt.show()

# %%
# Örnek veriler
num_points = 20  # Daha küçük bir numara kullanarak meshgrid boyutunu belirleme
x = np.linspace(0, 2 * np.pi, num_points)
y = np.linspace(0, 2 * np.pi, num_points)
X, Y = np.meshgrid(x, y)

# songDuration ve songPopularity verilerini normalize etme
U = data1['songDuration'].values[:num_points] / max(data1['songDuration'].values)  # Normalize songDuration
V = data1['songPopularity'].values[:num_points] / max(data1['songPopularity'].values)  # Normalize songPopularity

# Dizilerin boyutlarını eşleştir
U = np.resize(U, (num_points, num_points))
V = np.resize(V, (num_points, num_points))

# Barbs plot
plt.barbs(X, Y, U, V, length=5, pivot='middle')
plt.title('Barbs Plot - Spotify Duration vs Popularity')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# !pip install isodate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !pip install isodate # isodate modülünü indirme
import isodate

# Verileri birleştirme
data = pd.concat([data5, data6, data7, data8])

# ISO 8601 formatından milisaniyelere dönüştürme
def iso_to_ms(duration):
    duration_obj = isodate.parse_duration(duration)
    return duration_obj.total_seconds() * 1000

data['videoDurationMS'] = data['videoDuration'].apply(iso_to_ms)

# Örnek özellik seçimi ve normalize etme
num_points = 10  # Daha küçük bir numara kullanarak meshgrid boyutunu belirleme
x = np.linspace(0, 2 * np.pi, num_points)
y = np.linspace(0, 2 * np.pi, num_points)
X, Y = np.meshgrid(x, y)

# Özellikleri normalize etme
U = data['videoDurationMS'].values[:num_points] / max(data['videoDurationMS'].values)
V = data['viewCount'].values[:num_points] / max(data['viewCount'].values)

# Dizilerin boyutlarını eşleştirme
U = np.resize(U, (num_points, num_points))
V = np.resize(V, (num_points, num_points))

# Barbs plot
plt.barbs(X, Y, U, V, length=5, pivot='middle')
plt.title('Barbs Plot - YouTube Video Duration (ms) vs View Count')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
data = pd.concat([data5, data6, data7, data8])

# ISO 8601 formatından milisaniyelere dönüştürme
def iso_to_ms(duration):
    duration_obj = isodate.parse_duration(duration)
    return duration_obj.total_seconds() * 1000

data['videoDurationMS'] = data['videoDuration'].apply(iso_to_ms)
sinif = data["videoDurationMS"]

datalar = [sinif + i for i in range(len(sinif))]  # Farklı seriler oluşturma

# Event plot
plt.eventplot(datalar, orientation='horizontal', lineoffsets=1, colors='black')
plt.title('Event Plot - Youtube Video Duration')
plt.xlabel('Durations')
plt.ylabel('Series')
plt.show()

# %%
# Örnek veriler
x = data5['viewCount']
y = data6['likeCount']

# Hexbin plot
plt.hexbin(x, y, gridsize=30, cmap='Reds')
plt.colorbar(label='Count')
plt.title('Hexbin Plot - YouTube Views vs Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()

# %%
# İlk 10 şarkı için bar plot
top_10_songs = data3.head(10)
top_10_songs.plot(x='songName', y='songPopularity', kind='bar', color="pink", title='Top 10 Songs by Popularity in Spotify 2022')
plt.xlabel('Song Name')
plt.ylabel('Popularity')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
data = pd.concat([data5, data6, data7, data8])
# Scatter plot of Views vs. Likes
plt.figure(figsize=(10, 6))
plt.scatter(data['viewCount'], data['likeCount'], color='skyblue', alpha=0.7, edgecolors='black')
plt.title('Relationship between Views and Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.grid(True, linestyle='--', alpha=0.7)

# Adding a trendline
z = np.polyfit(data['viewCount'], data['likeCount'], 1)
p = np.poly1d(z)
plt.plot(data['viewCount'],p(data['likeCount']), color="red")

plt.show()
